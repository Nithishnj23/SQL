# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/zomato-bangalore-restaurants/zomato.csv

# %%
import pandas as pd
import sqlite3 as sql

# %%
## Read the file

df_zomato=pd.read_csv('/kaggle/input/zomato-bangalore-restaurants/zomato.csv')
df_zomato.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
## print the columns

print('The columns of the dataset are:- ',df_zomato.columns)
# Out:
# The columns of the dataset are:-  Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
# import sqlalchemy and create a sqlite engine
from sqlalchemy import create_engine
engine = create_engine('sqlite://', echo=False)

# export the dataframe as a table 'playstore' to the sqlite engine
df_zomato.to_sql("zomato", con =engine)

# %%
## Test the code by select the complete table

sql='''

Select * from zomato
limit 5


''';

    
df_sql = pd.read_sql_query(sql,con=engine)
df_sql.head()
# Out:
#    index                                                url  \
# 0      0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1      1  https://www.zomato.com/bangalore/spice-elephan...
# 2      2  https://www.zomato.com/SanchurroBangalore?cont...
# 3      3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4      4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# ...

# %%
## Count of Distinct Vendors

sql='''

Select 'The total number of vendors :- '||count(Distinct url) as Value from zomato

''';

    
df_sql = pd.read_sql_query(sql,con=engine)
df_sql.head()
# Out:
#                                   Value
# 0  The total number of vendors :- 51717

# %%
## Areas which with top vendors (for immediate food access and availability)

sql='''

Select location,count(Distinct url) as Value from zomato
group by 1
order by count(Distinct url) desc
''';

    
df_sql = pd.read_sql_query(sql,con=engine)
df_sql.head()
# Out:
#                 location  Value
# 0                    BTM   5124
# 1                    HSR   2523
# 2  Koramangala 5th Block   2504
# 3               JP Nagar   2235
# 4             Whitefield   2144

# %%
## Areas with vendos which have top ratings

## Areas which with top vendors (for immediate food access and availability)

sql='''

Select location,
round(avg(rate),2) as rating from zomato
group by 1
order by round(avg(rate),2) desc
''';

    
df_sql = pd.read_sql_query(sql,con=engine)
df_sql.head()
# Out:
#                 location  rating
# 0           Lavelle Road    4.04
# 1         St. Marks Road    4.02
# 2  Koramangala 3rd Block    3.98
# 3            Sankey Road    3.97
# 4          Church Street    3.96

# %%
## count of restaurants that have performed more than the average rating. Select a breakdown areawise

## Areas with vendos which have top ratings


sql='''

with b as (
select 
location,
name,
rate,
votes
from zomato
group by 1,2,3,4)

select * from
(select
s.location,
sum(case when s.rating>=3.7 then 1 else 0 end) as Above_avg_restuarants_count
from
(select
b.location,
b.name,
b.rate,
round(avg(b.rate),2) as rating,
b.votes
from b
where location!='None' and rate !='None'
group by 1,2,3,5 having b.votes >= avg(b.votes))s
group by 1) a
order by a.Above_avg_restuarants_count desc
''';

    
df_sql = pd.read_sql_query(sql,con=engine)
df_sql.head()
# Out:
#                 location  Above_avg_restuarants_count
# 0  Koramangala 5th Block                          808
# 1                    BTM                          749
# 2            Indiranagar                          745
# 3                    HSR                          681
# 4              Jayanagar                          567

# %%
## Area wise performance (TOtal number of vendors greater than avg rating and overall avg rating of the food)
sql='''

with b as (
select 
location,
name,
rate,
votes
from zomato
group by 1,2,3,4),

d as (
select location,
round(avg(rate),2) as rating from zomato
group by 1
order by round(avg(rate),2) desc)

select
a.location,
a.Above_avg_restuarants_count,
d.rating
from
(select
s.location,
sum(case when s.rating>=3.7 then 1 else 0 end) as Above_avg_restuarants_count
from
(select
b.location,
b.name,
b.rate,
round(avg(b.rate),2) as rating,
b.votes
from b
where location!='None' and rate !='None'
group by 1,2,3,5 having b.votes >= avg(b.votes))s
group by 1) a
join d on a.location=d.location
order by a.Above_avg_restuarants_count desc
''';

    
df_sql = pd.read_sql_query(sql,con=engine)
df_sql.head()
# Out:
#                 location  Above_avg_restuarants_count  rating
# 0  Koramangala 5th Block                          808    3.90
# 1                    BTM                          749    3.30
# 2            Indiranagar                          745    3.65
# 3                    HSR                          681    3.48
# 4              Jayanagar                          567    3.62
